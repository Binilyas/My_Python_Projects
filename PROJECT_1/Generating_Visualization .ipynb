# %% [markdown]
# # WELCOME TO MY 30DAYS OF PYTHON PROJECT 1
# ## TITLE: _GENERATING AND VISUALIZATION_

# %% [markdown]
# ###  Generate Synthetic Data
#
# For this example, let’s generate synthetic data that simulates sales data for a company over a period of 12 months.
#
# #### *Import the necessary libraries*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### _Generate synthetic sales data_

# %%
# Set random seed for reproducibility
np.random.seed(42)

# Generate monthly data for one year
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
sales = np.random.randint(5000, 15000, size=12)
expenses = sales * 0.75 + np.random.randint(2000, 5000, size=12)

# Create a DataFrame
df = pd.DataFrame({
    'Month': months,
    'Sales': sales,
    'Expenses': expenses
})

df.head()
# Out:
#   Month  Sales  Expenses
# 0   Jan  12270  13593.50
# 1   Feb   5860   7910.00
# 2   Mar  10390  12645.50
# 3   Apr  10191  12076.25
# 4   May  10734  11265.50

# %% [markdown]
# #### _Visualize the Data using Matplotlib_
# Line Plot for Sales and Expenses over the Year

# %%
plt.figure(figsize=(10, 6))

# Plot sales and expenses over months
plt.plot(df['Month'], df['Sales'], label='Sales', marker='o', linestyle='-', color='b')
plt.plot(df['Month'], df['Expenses'], label='Expenses', marker='o', linestyle='-', color='r')

# Adding labels and title
plt.title('Sales and Expenses Over the Year')
plt.xlabel('Month')
plt.ylabel('Amount in USD')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# ## _Bar Plot for Comparison of Sales and Expenses per Month_

# %%
# Set the positions of bars
x = np.arange(len(df['Month']))

# Bar plot for Sales and Expenses
plt.figure(figsize=(10, 6))

bar_width = 0.35
plt.bar(x - bar_width/2, df['Sales'], width=bar_width, label='Sales', color='green')
plt.bar(x + bar_width/2, df['Expenses'], width=bar_width, label='Expenses', color='red')

# Adding labels and title
plt.title('Sales vs Expenses Comparison by Month')
plt.xlabel('Month')
plt.ylabel('Amount in USD')
plt.xticks(x, df['Month'], rotation=45)
plt.legend()

plt.show()

# %% [markdown]
# ### _Perform Basic Data Analysis_
# Calculate Total Sales and Expenses for the Year

# %%
total_sales = df['Sales'].sum()
total_expenses = df['Expenses'].sum()

print(f"Total Sales for the Year: ${total_sales}")
print(f"Total Expenses for the Year: ${total_expenses}")
# Out:
# Total Sales for the Year: $111956
# Total Expenses for the Year: $126364.0

# %% [markdown]
# ### _Calculate Profit for Each Month_

# %%
df['Profit'] = df['Sales'] - df['Expenses']
df['Profit Margin'] = (df['Profit'] / df['Sales']) * 100

df[['Month', 'Sales', 'Expenses', 'Profit', 'Profit Margin']]
# Out:
#    Month  Sales  Expenses   Profit  Profit Margin
# 0    Jan  12270  13593.50 -1323.50     -10.786471
# 1    Feb   5860   7910.00 -2050.00     -34.982935
# 2    Mar  10390  12645.50 -2255.50     -21.708373
# 3    Apr  10191  12076.25 -1885.25     -18.499166
# 4    May  10734  11265.50  -531.50      -4.951556
# 5    Jun  11265  11403.75  -138.75      -1.231691
# 6    Jul   5466   8423.50 -2957.50     -54.107208
# 7    Aug   9426  10253.50  -827.50      -8.778909
# 8    Sep  10578  10392.50   185.50       1.753640
# 9    Oct  13322  12012.50  1309.50       9.829605
# 10   Nov   6685   9313.75 -2628.75     -39.323111
# 11   Dec   5769   7073.75 -1304.75     -22.616571

# %% [markdown]
# ## **Conclusion:**
#
# This is a simple Projects that generates synthetic sales data, visualizes it, and performs basic analysis such as profit calculation and correlation analysis.
